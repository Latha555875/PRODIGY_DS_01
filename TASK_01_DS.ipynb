# %%
import pandas as pd
filepath="/home/rguktongole/Downloads/ages_gender.xlsx"
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df=pd.read_excel(filepath)
print(df)
# Out:
#            Name  Age  Gender Branch        Id
# 0         Latha   18  Female    cse   O200699
# 1       Lavanya   19  Female    cse   O200534
# 2         Vamsi   23    Male    eee   O200764
# 3          Teja   23    Male    ece   O200620
# 4         Divya   20  Female    ece   O200617
# 5         Mouni   19  Female   mech   O200751
# 6         Kavya   19  Female  civil   O200203
# 7      Chandini   18  Female    cse   O200796
# 8         Durga   20  Female   mech   O200687
# 9       sahithi   21  Female   mech   O200708
# 10      Tejaswi   21  Female  civil   O200550
# 11       Ganesh   23    Male    cse   O200078
# 12     Bhavitha   22  Female    eee   O200854
# 13         Devi   19  Female    ece   O200685
# 14          Ram   19    Male    ece   O200923
# 15        Kiran   20    Male  civil   O200743
# 16      Karthik   21    Male   mech   O200721
# 17       Chitti   18  Female    eee   O200435
# 18        Varun   19    Male    ece   O200320
# 19      Maneesh   23  Female    cse   O200002
# 20        Shiva   19    Male    cse   O200546
# 21        Ranga   23    Male    cse   O200734
# 22       Bhagya   23  Female    eee   O200345
# 23      Lakshmi   20  Female    ece   O200714
# 24         Mani   19    Male    ece  O2000432
# 25         Vasu   19    Male   mech   O200475
# 26         Hari   18    Male  civil   O200198
# 27      Haritha   20  Female    cse   O200045
# 28        Tarak   21    Male   mech   O200046
# 29         Venu   21    Male   mech   O200047
# 30        Pooji   23  Female  civil   O200048
# 31         Kusu   22  Female    cse   O200049
# 32        Navya   19  Female    eee   O200050
# 33         Raju   19    Male    ece   O200051
# 34         Yash   20    Male    ece   O200052
# 35     Jaswanth   21    Male  civil   O200053
# 36      Mamatha   18  Female   mech   O200054
# 37       Anjali   19  Female    eee   O200055
# 38      Snigdha   23  Female    ece   O200056
# 39       Likith   18    Male    cse   O200057
# 40      Likitha   19  Female    ece   O200058
# 41       Pushpa   23  Female    cse   O200059
# 42     Mahidhar   23    Male    cse   O200060
# 43       Pavani   20  Female    cse   O200061
# 44     Bhargavi   19  Female    eee   O200062
# 45        Eswar   19    Male    ece   O200063
# 46          Ram   18    Male    ece   O200064
# 47       Karhik   20    Male   mech   O200065
# 48     Sireesha   21  Female  civil   O200066
# 49     Bharathi   21  Female    cse   O200067
# 50      Mounika   23  Female   mech   O200068
# 51      Sanjeev   22    Male   mech   O200069
# 52        Madhu   19    Male  civil   O200070
# 53   Venumadhav   19    Male    cse   O200071
# 54        Mohan   20    Male    eee   O200072
# 55        Ramya   21  Female    ece   O200073
# 56      Rachana   18  Female    ece   O200074
# 57      Avinash   19    Male  civil   O200075
# 58        Bindu   23  Female   mech   O200076
# 59       Renuka   19  Female    eee   O200077
# 60        Sunil   23    Male    ece   O200078
# 61       Mahesh   23    Male    cse   O200079
# 62        Ganga   20    Male    ece   O200080
# 63      Saiteja   19    Male    cse   O200081
# 64        Rupas   18    Male    cse   O200082
# 65      Nagaraj   19    Male    cse   O200083
# 66        Milky   23  Female    eee   O200084
# 67       Lahari   23  Female    ece   O200085
# 68      Haritha   20  Female    ece   O200086
# 69      Bhavika   19  Female   mech   O200087
# 70        Raghu   19    Male  civil   O200088
# 71      Vignesh   18    Male    cse   O200089
# 72        Ranga   20    Male   mech   O200090
# 73      Jahnavi   21  Female   mech   O200091
# 74      Sravika   21  Female  civil   O200092
# 75         Ravi   23    Male    cse   O200093
# 76       Mubina   22  Female    eee   O200094
# 77       Bhavya   19  Female    ece   O200095
# 78      Meghana   19  Female    ece   O200096
# 79       Nithin   20    Male  civil   O200097
# 80         Mark   21    Male   mech   O200098
# 81       Sanjiv   18    Male    eee   O200099
# 82     Kiranmai   19  Female    ece   O200100
# 83         Uday   23  Female    cse   O200101
# 84       Jyothi   19  Female    ece   O200102
# 85        Bhanu   23    Male    cse   O200103
# 86        Swami   23    Male    cse   O200104
# 87       Muskan   20  Female    cse   O200105
# 88      Hassena   19  Female    eee   O200106
# 89  Chandrakala   18  Female    ece   O200107
# 90       Dinesh   19    Male    ece   O200108
# 91       karuna   23  Female   mech   O200109
# 92     Shailesh   23    Male  civil   O200110
# 93       Sriram   20    Male    cse   O200111
# 94      Swarrop   19    Male   mech   O200112
# 95        Rohit   19    Male   mech   O200113
# 96        Virat   18    Male  civil   O200114
# 97       Hardik   20    Male    cse   O200115
# 98      Nandini   21  Female    eee   O200116
# 99        Pooja   21  Female    ece   O200117

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'ages_gender.xlsx' contains your data with a column 'Gender' 
# Load your dataset
df = pd.read_excel('/home/rguktongole/Downloads/ages_gender.xlsx')

#  Bar Chart for Categorical Data ('Gender')

gender_counts = df['Gender'].value_counts()
print(df[['Name','Gender']].head(10))
plt.bar(gender_counts.index, gender_counts.values,color='orange')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Genders using BarCharts ')
plt.show()
# Out:
#        Name  Gender
# 0     Latha  Female
# 1   Lavanya  Female
# 2     Vamsi    Male
# 3      Teja    Male
# 4     Divya  Female
# 5     Mouni  Female
# 6     Kavya  Female
# 7  Chandini  Female
# 8     Durga  Female
# 9   sahithi  Female

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'ages_gender.xlsx' contains your data with a column 'Age'
# Load your dataset

df = pd.read_excel('/home/rguktongole/Downloads/ages_gender.xlsx')

#  Bar Chart for Categorical Data  ('Age')

age_counts = df['Age'].value_counts().sort_index()
print(df[['Name','Age']].head(10))
plt.bar(age_counts.index, age_counts.values,width=0.5,color='brown')
plt.xlabel('Ages')
plt.ylabel('Count')
plt.title('Distribution of Age using Bar graph')
plt.show()
# Out:
#        Name  Age
# 0     Latha   18
# 1   Lavanya   19
# 2     Vamsi   23
# 3      Teja   23
# 4     Divya   20
# 5     Mouni   19
# 6     Kavya   19
# 7  Chandini   18
# 8     Durga   20
# 9   sahithi   21

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (replace 'ages_genders.xlsx' with your actual file path)

df = pd.read_excel('/home/rguktongole/Downloads/ages_gender.xlsx')

# Assuming 'Age' is the column containing age data
print(df[['Name','Age']].head(10))
plt.hist(df['Age'], bins=5,color="green")
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.title('Distribution of Ages using histogram')
plt.show()
# Out:
#        Name  Age
# 0     Latha   18
# 1   Lavanya   19
# 2     Vamsi   23
# 3      Teja   23
# 4     Divya   20
# 5     Mouni   19
# 6     Kavya   19
# 7  Chandini   18
# 8     Durga   20
# 9   sahithi   21

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (replace 'ages_genders.xlsx' with your actual file path)

df = pd.read_excel('/home/rguktongole/Downloads/ages_gender.xlsx')

# Assuming 'Gender' is the column containing age data
print(df[['Name','Gender']].head(10))
plt.hist(df['Gender'], bins=2,color="purple")
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Genders using histogram')
plt.show()
# Out:
#        Name  Gender
# 0     Latha  Female
# 1   Lavanya  Female
# 2     Vamsi    Male
# 3      Teja    Male
# 4     Divya  Female
# 5     Mouni  Female
# 6     Kavya  Female
# 7  Chandini  Female
# 8     Durga  Female
# 9   sahithi  Female
